# %%
from datetime import datetime
import hashlib
import os
import os.path
import random
import re
import sys
import tarfile

import numpy as np
from six.moves import urllib
import tensorflow as tf

from tensorflow.contrib.quantize.python import quant_ops
from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat

MIN_NUM_IMAGES_REQUIRED_FOR_TRAINING = 10
MIN_NUM_IMAGES_SUGGESTED_FOR_TRAINING = 100

MIN_NUM_IMAGES_REQUIRED_FOR_TESTING = 3

MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M

#TRAINING_IMAGES_DIR
# path to folders of labeled images
TRAINING_IMAGES_DIR = 'data/training_images/'

TEST_IMAGES_DIR = "data/test_images/"

# %%
# where to save the trained graph
OUTPUT_GRAPH = os.getcwd() + '/' + 'retrained_graph.pb'

# where to save the intermediate graphs
INTERMEDIATE_OUTPUT_GRAPHS_DIR = os.getcwd() + '/intermediate_graph'

# how many steps to store intermediate graph, if "0" then will not store
INTERMEDIATE_STORE_FREQUENCY = 0

# where to save the trained graph's labels
OUTPUT_LABELS = os.getcwd() + '/' + 'retrained_labels.txt'

# where to save summary logs for TensorBoard
TENSORBOARD_DIR = os.getcwd() + '/' + 'tensorboard_logs'

# how many training steps to run before ending
# NOTE: original Google default is 4000, use 4000 (or possibly higher) for production grade results
HOW_MANY_TRAINING_STEPS=500

# how large a learning rate to use when training
LEARNING_RATE = 0.01

# what percentage of images to use as a test set
TESTING_PERCENTAGE = 10

# what percentage of images to use as a validation set
VALIDATION_PERCENTAGE = 10

# how often to evaluate the training results
EVAL_STEP_INTERVAL = 10

# how many images to train on at a time
TRAIN_BATCH_SIZE = 100

# How many images to test on. This test set is only used once, to evaluate the final accuracy of the model after
# training completes.  A value of -1 causes the entire test set to be used, which leads to more stable results across runs.
TEST_BATCH_SIZE = -1

# How many images to use in an evaluation batch. This validation set is used much more often than the test set, and is an early indicator of how
# accurate the model is during training. A value of -1 causes the entire validation set to be used, which leads to
# more stable results across training iterations, but may be slower on large training sets.
VALIDATION_BATCH_SIZE = 100

# whether to print out a list of all misclassified test images
PRINT_MISCLASSIFIED_TEST_IMAGES = False

# Path to classify_image_graph_def.pb, imagenet_synset_to_human_label_map.txt, and imagenet_2012_challenge_label_map_proto.pbtxt
MODEL_DIR = os.getcwd() + "/" + "model"

# Path to cache bottleneck layer values as files
BOTTLENECK_DIR = os.getcwd() + '/' + 'bottleneck_data'

# the name of the output classification layer in the retrained graph
FINAL_TENSOR_NAME = 'final_result'

# whether to randomly flip half of the training images horizontally
FLIP_LEFT_RIGHT = False

# a percentage determining how much of a margin to randomly crop off the training images
RANDOM_CROP = 0

# a percentage determining how much to randomly scale up the size of the training images by
RANDOM_SCALE = 0

# a percentage determining how much to randomly multiply the training image input pixels up or down by
RANDOM_BRIGHTNESS = 0

# Which model architecture to use. 'inception_v3' is the most accurate, but also the slowest. For faster or smaller models, chose a MobileNet with
# the form 'mobilenet_<parameter size>_<input_size>[_quantized]'. For example, 'mobilenet_1.0_224' will pick a model that is 17 MB in size and takes
# 224 pixel input images, while 'mobilenet_0.25_128_quantized' will choose a much less accurate, but smaller and faster network that's 920 KB
# on disk and takes 128x128 images. See https://research.googleblog.com/2017/06/mobilenets-open-source-models-for.html for more information on Mobilenet.

# By default this script will use the high accuracy, but comparatively large and slow Inception v3 model architecture.
# It's recommended that you start with this to validate that you have gathered good training data, but if you want to deploy
# on resource-limited platforms, you can try the `--architecture` flag with a Mobilenet model. For example:

# example command to run floating-point version of mobilenet:
# ARCHITECTURE = 'mobilenet_1.0_224'

# example command to run quantized version of mobilenet:
# ARCHITECTURE = 'mobilenet_1.0_224_quantized'

# There are 32 different Mobilenet models to choose from, with a variety of file size and latency options. The first
# number can be '1.0', '0.75', '0.50', or '0.25' to control the size, and the second controls the input image size,
# either '224', '192', '160', or '128', with smaller sizes running faster.
# See https://research.googleblog.com/2017/06/mobilenets-open-source-models-for.html for more information on Mobilenet.
ARCHITECTURE = 'inception_v3'

#######################################################################################################################
def main():
    print("starting program . . .")
    # make sure the logging output is visible, see https://github.com/tensorflow/tensorflow/issues/3047
    tf.logging.set_verbosity(tf.logging.INFO)

    if not checkIfNecessaryPathsAndFilesExist():
        return
    # end if

    # prepare necessary directories that can be used during training
    prepare_file_system()

    # Gather information about the model architecture we'll be using.
    model_info = create_model_info(ARCHITECTURE)
    if not model_info:
        tf.logging.error('Did not recognize architecture flag')
        return -1
    # end if

    # download the model if necessary, then create the model graph
    print("downloading model (if necessary) . . .")
    downloadModelIfNotAlreadyPresent(model_info['data_url'])
    print("creating model graph . . .")
    graph, bottleneck_tensor, resized_image_tensor = (create_model_graph(model_info))

    # Look at the folder structure, and create lists of all the images.
    print("creating image lists . . .")
    image_lists = create_image_lists(TRAINING_IMAGES_DIR, TESTING_PERCENTAGE, VALIDATION_PERCENTAGE)
    class_count = len(image_lists.keys())
    if class_count == 0:
        tf.logging.error('No valid folders of images found at ' + TRAINING_IMAGES_DIR)
        return -1
    # end if
    if class_count == 1:
        tf.logging.error('Only one valid folder of images found at ' + TRAINING_IMAGES_DIR + ' - multiple classes are needed for classification.')
        return -1
    # end if

    # determinf if any of the distortion command line flags have been set
    doDistortImages = False
    if (FLIP_LEFT_RIGHT == True or RANDOM_CROP != 0 or RANDOM_SCALE != 0 or RANDOM_BRIGHTNESS != 0):
        doDistortImages = True
    # end if

    print("starting session . . .")
    with tf.Session(graph=graph) as sess:
        # Set up the image decoding sub-graph.
        print("performing jpeg decoding . . .")
        jpeg_data_tensor, decoded_image_tensor = add_jpeg_decoding( model_info['input_width'],
                                                                    model_info['input_height'],
                                                                    model_info['input_depth'],
                                                                    model_info['input_mean'],
                                                                    model_info['input_std'])
        print("caching bottlenecks . . .")
        distorted_jpeg_data_tensor = None
        distorted_image_tensor = None
        if doDistortImages:
            # We will be applying distortions, so setup the operations we'll need.
            (distorted_jpeg_data_tensor, distorted_image_tensor) = add_input_distortions(FLIP_LEFT_RIGHT, RANDOM_CROP, RANDOM_SCALE,
                                                                                         RANDOM_BRIGHTNESS, model_info['input_width'],
                                                                                         model_info['input_height'], model_info['input_depth'],
                                                                                         model_info['input_mean'], model_info['input_std'])
        else:
            # We'll make sure we've calculated the 'bottleneck' image summaries and
            # cached them on disk.
            cache_bottlenecks(sess, image_lists, TRAINING_IMAGES_DIR, BOTTLENECK_DIR, jpeg_data_tensor, decoded_image_tensor,
                              resized_image_tensor, bottleneck_tensor, ARCHITECTURE)
        # end if

        # Add the new layer that we'll be training.
        print("adding final training layer . . .")
        (train_step, cross_entropy, bottleneck_input, ground_truth_input, final_tensor) = add_final_training_ops(len(image_lists.keys()),
                                                                                                                 FINAL_TENSOR_NAME,
                                                                                                                 bottleneck_tensor,
                                                                                                                 model_info['bottleneck_tensor_size'],
                                                                                                                 model_info['quantize_layer'])
        # Create the operations we need to evaluate the accuracy of our new layer.
        print("adding eval ops for final training layer . . .")
        evaluation_step, prediction = add_evaluation_step(final_tensor, ground_truth_input)

        # Merge all the summaries and write them out to the tensorboard_dir
        print("writing TensorBoard info . . .")
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(TENSORBOARD_DIR + '/train', sess.graph)
        validation_writer = tf.summary.FileWriter(TENSORBOARD_DIR + '/validation')

        # Set up all our weights to their initial default values.
        init = tf.global_variables_initializer()
        sess.run(init)

        # Run the training for as many cycles as requested on the command line.
        print("performing training . . .")
        for i in range(HOW_MANY_TRAINING_STEPS):
            # Get a batch of input bottleneck values, either calculated fresh every
            # time with distortions applied, or from the cache stored on disk.
            if doDistortImages:
                (train_bottlenecks, train_ground_truth) = get_random_distorted_bottlenecks(sess, image_lists, TRAIN_BATCH_SIZE, 'training',
                                                                                           TRAINING_IMAGES_DIR, distorted_jpeg_data_tensor,
                                                                                           distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
            else:
                (train_bottlenecks, train_ground_truth, _) = get_random_cached_bottlenecks(sess, image_lists, TRAIN_BATCH_SIZE, 'training',
                                                                                           BOTTLENECK_DIR, TRAINING_IMAGES_DIR, jpeg_data_tensor,
                                                                                           decoded_image_tensor, resized_image_tensor, bottleneck_tensor,
                                                                                           ARCHITECTURE)
            # end if

            # Feed the bottlenecks and ground truth into the graph, and run a training
            # step. Capture training summaries for TensorBoard with the `merged` op.
            train_summary, _ = sess.run([merged, train_step], feed_dict={bottleneck_input: train_bottlenecks, ground_truth_input: train_ground_truth})
            train_writer.add_summary(train_summary, i)

            # Every so often, print out how well the graph is training.
            is_last_step = (i + 1 == HOW_MANY_TRAINING_STEPS)
            if (i % EVAL_STEP_INTERVAL) == 0 or is_last_step:
                train_accuracy, cross_entropy_value = sess.run([evaluation_step, cross_entropy], feed_dict={bottleneck_input: train_bottlenecks, ground_truth_input: train_ground_truth})
                tf.logging.info('%s: Step %d: Train accuracy = %.1f%%' % (datetime.now(), i, train_accuracy * 100))
                tf.logging.info('%s: Step %d: Cross entropy = %f' % (datetime.now(), i, cross_entropy_value))
                validation_bottlenecks, validation_ground_truth, _ = (get_random_cached_bottlenecks(sess, image_lists, VALIDATION_BATCH_SIZE, 'validation',
                                                                                                    BOTTLENECK_DIR, TRAINING_IMAGES_DIR, jpeg_data_tensor,
                                                                                                    decoded_image_tensor, resized_image_tensor, bottleneck_tensor,
                                                                                                    ARCHITECTURE))
                # Run a validation step and capture training summaries for TensorBoard with the `merged` op.
                validation_summary, validation_accuracy = sess.run(
                    [merged, evaluation_step], feed_dict={bottleneck_input: validation_bottlenecks, ground_truth_input: validation_ground_truth})
                validation_writer.add_summary(validation_summary, i)
                tf.logging.info('%s: Step %d: Validation accuracy = %.1f%% (N=%d)' % (datetime.now(), i, validation_accuracy * 100, len(validation_bottlenecks)))
            # end if

            # Store intermediate results
            intermediate_frequency = INTERMEDIATE_STORE_FREQUENCY

            if (intermediate_frequency > 0 and (i % intermediate_frequency == 0) and i > 0):
                intermediate_file_name = (INTERMEDIATE_OUTPUT_GRAPHS_DIR + 'intermediate_' + str(i) + '.pb')
                tf.logging.info('Save intermediate result to : ' + intermediate_file_name)
                save_graph_to_file(sess, graph, intermediate_file_name)
            # end if
        # end for

        # We've completed all our training, so run a final test evaluation on some new images we haven't used before
        print("running testing . . .")
        test_bottlenecks, test_ground_truth, test_filenames = (get_random_cached_bottlenecks(sess, image_lists, TEST_BATCH_SIZE, 'testing', BOTTLENECK_DIR,
                                                                                             TRAINING_IMAGES_DIR, jpeg_data_tensor, decoded_image_tensor, resized_image_tensor,
                                                                                             bottleneck_tensor, ARCHITECTURE))
        test_accuracy, predictions = sess.run([evaluation_step, prediction], feed_dict={bottleneck_input: test_bottlenecks, ground_truth_input: test_ground_truth})
        tf.logging.info('Final test accuracy = %.1f%% (N=%d)' % (test_accuracy * 100, len(test_bottlenecks)))

        if PRINT_MISCLASSIFIED_TEST_IMAGES:
            tf.logging.info('=== MISCLASSIFIED TEST IMAGES ===')
            for i, test_filename in enumerate(test_filenames):
                if predictions[i] != test_ground_truth[i]:
                    tf.logging.info('%70s  %s' % (test_filename, list(image_lists.keys())[predictions[i]]))
                # end if
            # end for
        # end if

        # write out the trained graph and labels with the weights stored as constants
        print("writing trained graph and labbels with weights")
        save_graph_to_file(sess, graph, OUTPUT_GRAPH)
        with gfile.FastGFile(OUTPUT_LABELS, 'w') as f:
            f.write('\n'.join(image_lists.keys()) + '\n')
        # end with

        print("done !!")
# end function

#######################################################################################################################
def checkIfNecessaryPathsAndFilesExist():
    # if the training directory does not exist, show and error message and bail
    if not os.path.exists(TRAINING_IMAGES_DIR):
        print('')
        print('ERROR: TRAINING_IMAGES_DIR "' + TRAINING_IMAGES_DIR + '" does not seem to exist')
        print('Did you set up the training images?')
        print('')
        return False
    # end if

    # nested class
    class TrainingSubDir:
        # constructor
        def __init__(self):
            self.loc = ""
            self.numImages = 0
        # end constructor
    # end class

    # declare a list of training sub-directories
    trainingSubDirs = []

    # populate the training sub-directories
    for dirName in os.listdir(TRAINING_IMAGES_DIR):
        currentTrainingImagesSubDir = os.path.join(TRAINING_IMAGES_DIR, dirName)
        if os.path.isdir(currentTrainingImagesSubDir):
            trainingSubDir = TrainingSubDir()
            trainingSubDir.loc = currentTrainingImagesSubDir
            trainingSubDirs.append(trainingSubDir)
        # end if
    # end for

    # if no training sub-directories were found, show an error message and return false
    if len(trainingSubDirs) == 0:
        print("ERROR: there don't seem to be any training image sub-directories in " + TRAINING_IMAGES_DIR)
        print("Did you make a separare image sub-directory for each classification type?")
        return False
    # end if

    # populate the number of training images in each training sub-directory
    for trainingSubDir in trainingSubDirs:
        # count how many images are in the current training sub-directory
        for fileName in os.listdir(trainingSubDir.loc):
            if fileName.endswith(".jpg"):
                trainingSubDir.numImages += 1
            # end if
        # end if
    # end for

    # if any training sub-directory has less than the min required number of training images, show an error message and return false
    for trainingSubDir in trainingSubDirs:
        if trainingSubDir.numImages < MIN_NUM_IMAGES_REQUIRED_FOR_TRAINING:
            print("ERROR: there are less than the required " + str(MIN_NUM_IMAGES_REQUIRED_FOR_TRAINING) + " images in " + trainingSubDir.loc)
            print("Did you populate each training sub-directory with images?")
            return False
        # end if
    # end for

    # if any training sub-directory has less than the recommended number of training images, show a warning (but don't return false)
    for trainingSubDir in trainingSubDirs:
        if trainingSubDir.numImages < MIN_NUM_IMAGES_SUGGESTED_FOR_TRAINING:
            print("WARNING: there are less than the suggested " + str(MIN_NUM_IMAGES_SUGGESTED_FOR_TRAINING) + " images in " + trainingSubDir.loc)
            print("More images should be added to this directory for acceptable training results")
            # note we do not return false here b/c this is a warning, not an error
        # end if
    # end for

    # if the test images directory does not exist, show and error message and bail
    if not os.path.exists(TEST_IMAGES_DIR):
        print('')
        print('ERROR: TEST_IMAGES_DIR "' + TEST_IMAGES_DIR + '" does not seem to exist')
        print('Did you break out some test images?')
        print('')
        return False
    # end if

    # count how many images are in the test images directory
    numImagesInTestDir = 0
    for fileName in os.listdir(TEST_IMAGES_DIR):
        if fileName.endswith(".jpg"):
            numImagesInTestDir += 1
        # end if
    # end for

    # if there are not enough images in the test images directory, show an error and return false
    if numImagesInTestDir < MIN_NUM_IMAGES_REQUIRED_FOR_TESTING:
        print("ERROR: there are not at least " + str(MIN_NUM_IMAGES_REQUIRED_FOR_TESTING) + " images in " + TEST_IMAGES_DIR)
        print("Did you break out some test images?")
        return False
    # end if

    return True
# end function

#######################################################################################################################
def prepare_file_system():
    # Setup the directory we'll write summaries to for TensorBoard
    if tf.gfile.Exists(TENSORBOARD_DIR):
        tf.gfile.DeleteRecursively(TENSORBOARD_DIR)
    # end if
    tf.gfile.MakeDirs(TENSORBOARD_DIR)
    if INTERMEDIATE_STORE_FREQUENCY > 0:
        makeDirIfDoesNotExist(INTERMEDIATE_OUTPUT_GRAPHS_DIR)
    # end if
    return
# end function

#######################################################################################################################
def makeDirIfDoesNotExist(dir_name):
    """
    Makes sure the folder exists on disk.
    Args:
        dir_name: Path string to the folder we want to create.
    """
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    # end if
# end function

#######################################################################################################################
def create_model_info(architecture):
    """
    Given the name of a model architecture, returns information about it.

    There are different base image recognition pretrained models that can be
    retrained using transfer learning, and this function translates from the name
    of a model to the attributes that are needed to download and train with it.

    Args:
        architecture: Name of a model architecture.

    Returns:
        Dictionary of information about the model, or None if the name isn't recognized

    Raises:
        ValueError: If architecture name is unknown.
    """
    architecture = architecture.lower()
    is_quantized = False
    if architecture == 'inception_v3':
        # pylint: disable=line-too-long
        data_url = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'
        # pylint: enable=line-too-long
        bottleneck_tensor_name = 'pool_3/_reshape:0'
        bottleneck_tensor_size = 2048
        input_width = 299
        input_height = 299
        input_depth = 3
        resized_input_tensor_name = 'Mul:0'
        model_file_name = 'classify_image_graph_def.pb'
        input_mean = 128
        input_std = 128
    elif architecture.startswith('mobilenet_'):
        parts = architecture.split('_')
        if len(parts) != 3 and len(parts) != 4:
            tf.logging.error("Couldn't understand architecture name '%s'", architecture)
            return None
        # end if
        version_string = parts[1]
        if (version_string != '1.0' and version_string != '0.75' and version_string != '0.50' and version_string != '0.25'):
            tf.logging.error(""""The Mobilenet version should be '1.0', '0.75', '0.50', or '0.25', but found '%s' for architecture '%s'""", version_string, architecture)
            return None
        # end if
        size_string = parts[2]
        if (size_string != '224' and size_string != '192' and size_string != '160' and size_string != '128'):
            tf.logging.error("""The Mobilenet input size should be '224', '192', '160', or '128', but found '%s' for architecture '%s'""", size_string, architecture)
            return None
        # end if
        if len(parts) == 3:
            is_quantized = False
        else:
            if parts[3] != 'quantized':
                tf.logging.error(
                    "Couldn't understand architecture suffix '%s' for '%s'", parts[3], architecture)
                return None
            is_quantized = True
        # end if

        if is_quantized:
            data_url = 'http://download.tensorflow.org/models/mobilenet_v1_'
            data_url += version_string + '_' + size_string + '_quantized_frozen.tgz'
            bottleneck_tensor_name = 'MobilenetV1/Predictions/Reshape:0'
            resized_input_tensor_name = 'Placeholder:0'
            model_dir_name = ('mobilenet_v1_' + version_string + '_' + size_string + '_quantized_frozen')
            model_base_name = 'quantized_frozen_graph.pb'
        else:
            data_url = 'http://download.tensorflow.org/models/mobilenet_v1_'
            data_url += version_string + '_' + size_string + '_frozen.tgz'
            bottleneck_tensor_name = 'MobilenetV1/Predictions/Reshape:0'
            resized_input_tensor_name = 'input:0'
            model_dir_name = 'mobilenet_v1_' + version_string + '_' + size_string
            model_base_name = 'frozen_graph.pb'
        # end if

        bottleneck_tensor_size = 1001
        input_width = int(size_string)
        input_height = int(size_string)
        input_depth = 3
        model_file_name = os.path.join(model_dir_name, model_base_name)
        input_mean = 127.5
        input_std = 127.5
    else:
        tf.logging.error("Couldn't understand architecture name '%s'", architecture)
        raise ValueError('Unknown architecture', architecture)
    # end if

    return {'data_url': data_url, 'bottleneck_tensor_name': bottleneck_tensor_name, 'bottleneck_tensor_size': bottleneck_tensor_size,
            'input_width': input_width, 'input_height': input_height, 'input_depth': input_depth, 'resized_input_tensor_name': resized_input_tensor_name,
            'model_file_name': model_file_name, 'input_mean': input_mean, 'input_std': input_std, 'quantize_layer': is_quantized, }
# end function

#######################################################################################################################
def downloadModelIfNotAlreadyPresent(data_url):
    """
    Download and extract model tar file.

    If the pretrained model we're using doesn't already exist, this function downloads it from the TensorFlow.org website and unpacks it into a directory.

    Args:
        data_url: Web location of the tar file containing the pretrained model.
    """
    dest_directory = MODEL_DIR
    if not os.path.exists(dest_directory):
        os.makedirs(dest_directory)
    # end if
    filename = data_url.split('/')[-1]
    filepath = os.path.join(dest_directory, filename)
    if not os.path.exists(filepath):
        # nested function
        def _progress(count, block_size, total_size):
            sys.stdout.write('\r>> Downloading %s %.1f%%' % (filename, float(count * block_size) / float(total_size) * 100.0))
            sys.stdout.flush()
        # end def

        filepath, _ = urllib.request.urlretrieve(data_url, filepath, _progress)
        print()
        statinfo = os.stat(filepath)
        tf.logging.info('Successfully downloaded ' + str(filename) + ', statinfo.st_size = ' + str(statinfo.st_size) + ' bytes')
        print('Extracting file from ', filepath)
        tarfile.open(filepath, 'r:gz').extractall(dest_directory)
    else:
        print('Not extracting or downloading files, model already present in disk')
    # end if
# end function

#######################################################################################################################
def create_model_graph(model_info):
    """"
    Creates a graph from saved GraphDef file and returns a Graph object.

    Args:
        model_info: Dictionary containing information about the model architecture.

    Returns:
        Graph holding the trained Inception network, and various tensors we'll be manipulating.
    """
    with tf.Graph().as_default() as graph:
        model_path = os.path.join(MODEL_DIR, model_info['model_file_name'])
        print('Model path: ', model_path)
        with gfile.FastGFile(model_path, 'rb') as f:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(f.read())
            bottleneck_tensor, resized_input_tensor = (tf.import_graph_def(graph_def, name='', return_elements=[model_info['bottleneck_tensor_name'], model_info['resized_input_tensor_name'],]))
        # end with
    # end with
    return graph, bottleneck_tensor, resized_input_tensor
# end function

#######################################################################################################################
def create_image_lists(image_dir, testing_percentage, validation_percentage):
    """
    Builds a list of training images from the file system.

    Analyzes the sub folders in the image directory, splits them into stable
    training, testing, and validation sets, and returns a data structure
    describing the lists of images for each label and their paths.

    Args:
        image_dir: String path to a folder containing subfolders of images.
        testing_percentage: Integer percentage of the images to reserve for tests.
        validation_percentage: Integer percentage of images reserved for validation.

    Returns:
        A dictionary containing an entry for each label subfolder, with images split
        into training, testing, and validation sets within each label.
    """

    # if the image directory does not exist, log an error and bail
    if not gfile.Exists(image_dir):
        tf.logging.error("Image directory '" + image_dir + "' not found.")
        return None
    # end if

    # create an empty dictionary to store the results
    result = {}

    # get a list of the sub-directories of the image directory
    sub_dirs = [x[0] for x in gfile.Walk(image_dir)]

    # for each directory in the sub-directories list . . .
    is_root_dir = True
    for sub_dir in sub_dirs:
        # if we're on the 1st (root) directory, mark our boolean for that as false for the next time around and go back to the top of the for loop
        if is_root_dir:
            is_root_dir = False
            continue
        # end if

        dir_name = os.path.basename(sub_dir)
        if dir_name == image_dir:
            continue
        # end if

        # ToDo: This section should be refactored.  The right way to do this would be to get a list of the files that are
        # ToDo: there then append (extend) those, not to get the name except the extension, then append an extension,
        # ToDo: this (current) way is error prone of the original file has an upper case or mixed case extension

        extensions = ['jpg', 'jpeg']
        file_list = []
        tf.logging.info("Looking for images in '" + dir_name + "'")
        for extension in extensions:
            file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
            file_list.extend(gfile.Glob(file_glob))
        # end for

        # if the file list is empty at this point, log a warning and bail
        if not file_list:
            tf.logging.warning('No files found')
            continue
        # end if

        # if the length of the file list is less than 20 or more than the max number, log an applicable warning (do not return, however)
        if len(file_list) < 20:
            tf.logging.warning('WARNING: Folder has less than 20 images, which may cause issues.')
        elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
            tf.logging.warning('WARNING: Folder {} has more than {} images. Some images will never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
        # end if

        label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
        training_images = []
        testing_images = []
        validation_images = []
        for file_name in file_list:
            base_name = os.path.basename(file_name)
            # We want to ignore anything after '_nohash_' in the file name when deciding which set to put an image in, the data set creator
            # has a way of grouping photos that are close variations of each other. For example this is used in the plant disease data set
            # to group multiple pictures of the same leaf.
            hash_name = re.sub(r'_nohash_.*$', '', file_name)
            # This looks a bit magical, but we need to decide whether this file should go into the training, testing, or validation sets,
            # and we want to keep existing files in the same set even if more files are subsequently added.  To do that, we need a stable
            # way of deciding based on just the file name itself, so we do a hash of that and then use that to generate a probability value
            # that we use to assign it.
            hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
            percentage_hash = ((int(hash_name_hashed, 16) % (MAX_NUM_IMAGES_PER_CLASS + 1)) * (100.0 / MAX_NUM_IMAGES_PER_CLASS))
            if percentage_hash < validation_percentage:
                validation_images.append(base_name)
            elif percentage_hash < (testing_percentage + validation_percentage):
                testing_images.append(base_name)
            else:
                training_images.append(base_name)
            # end if
        result[label_name] = {'dir': dir_name, 'training': training_images, 'testing': testing_images, 'validation': validation_images,}
    return result
# end function

#######################################################################################################################
def add_jpeg_decoding(input_width, input_height, input_depth, input_mean, input_std):
    """
    Adds operations that perform JPEG decoding and resizing to the graph..
    Args:
        input_width: Desired width of the image fed into the recognizer graph.
        input_height: Desired width of the image fed into the recognizer graph.
        input_depth: Desired channels of the image fed into the recognizer graph.
        input_mean: Pixel value that should be zero in the image for the graph.
        input_std: How much to divide the pixel values by before recognition.

    Returns:
        Tensors for the node to feed JPEG data into, and the output of the preprocessing steps.
    """
    jpeg_data = tf.placeholder(tf.string, name='DecodeJPGInput')
    decoded_image = tf.image.decode_jpeg(jpeg_data, channels=input_depth)
    decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
    decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
    resize_shape = tf.stack([input_height, input_width])
    resize_shape_as_int = tf.cast(resize_shape, dtype=tf.int32)
    resized_image = tf.image.resize_bilinear(decoded_image_4d, resize_shape_as_int)
    offset_image = tf.subtract(resized_image, input_mean)
    mul_image = tf.multiply(offset_image, 1.0 / input_std)
    return jpeg_data, mul_image
# end function

#######################################################################################################################
def add_input_distortions(flip_left_right, random_crop, random_scale, random_brightness, input_width, input_height,
                          input_depth, input_mean, input_std):
    """
    Creates the operations to apply the specified distortions.

    During training it can help to improve the results if we run the images
    through simple distortions like crops, scales, and flips. These reflect the
    kind of variations we expect in the real world, and so can help train the
    model to cope with natural data more effectively. Here we take the supplied
    parameters and construct a network of operations to apply them to an image.

    Cropping
    ~~~~~~~~

    Cropping is done by placing a bounding box at a random position in the full
    image. The cropping parameter controls the size of that box relative to the
    input image. If it's zero, then the box is the same size as the input and no
    cropping is performed. If the value is 50%, then the crop box will be half the
    width and height of the input. In a diagram it looks like this:

    <       width         >
    +---------------------+
    |                     |
    |   width - crop%     |
    |    <      >         |
    |    +------+         |
    |    |      |         |
    |    |      |         |
    |    |      |         |
    |    +------+         |
    |                     |
    |                     |
    +---------------------+

    Scaling
    ~~~~~~~

    Scaling is a lot like cropping, except that the bounding box is always
    centered and its size varies randomly within the given range. For example if
    the scale percentage is zero, then the bounding box is the same size as the
    input and no scaling is applied. If it's 50%, then the bounding box will be in
    a random range between half the width and height and full size.

    Args:
        flip_left_right: Boolean whether to randomly mirror images horizontally.
        random_crop: Integer percentage setting the total margin used around the
        crop box.
        random_scale: Integer percentage of how much to vary the scale by.
        random_brightness: Integer range to randomly multiply the pixel values by.
        graph.
        input_width: Horizontal size of expected input image to model.
        input_height: Vertical size of expected input image to model.
        input_depth: How many channels the expected input image should have.
        input_mean: Pixel value that should be zero in the image for the graph.
        input_std: How much to divide the pixel values by before recognition.

    Returns:
        The jpeg input layer and the distorted result tensor.
    """

    jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
    decoded_image = tf.image.decode_jpeg(jpeg_data, channels=input_depth)
    decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
    decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
    margin_scale = 1.0 + (random_crop / 100.0)
    resize_scale = 1.0 + (random_scale / 100.0)
    margin_scale_value = tf.constant(margin_scale)
    resize_scale_value = tf.random_uniform(tensor_shape.scalar(), minval=1.0, maxval=resize_scale)
    scale_value = tf.multiply(margin_scale_value, resize_scale_value)
    precrop_width = tf.multiply(scale_value, input_width)
    precrop_height = tf.multiply(scale_value, input_height)
    precrop_shape = tf.stack([precrop_height, precrop_width])
    precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
    precropped_image = tf.image.resize_bilinear(decoded_image_4d, precrop_shape_as_int)
    precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
    cropped_image = tf.random_crop(precropped_image_3d, [input_height, input_width, input_depth])
    if flip_left_right:
        flipped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        flipped_image = cropped_image
    # end if
    brightness_min = 1.0 - (random_brightness / 100.0)
    brightness_max = 1.0 + (random_brightness / 100.0)
    brightness_value = tf.random_uniform(tensor_shape.scalar(), minval=brightness_min, maxval=brightness_max)
    brightened_image = tf.multiply(flipped_image, brightness_value)
    offset_image = tf.subtract(brightened_image, input_mean)
    mul_image = tf.multiply(offset_image, 1.0 / input_std)
    distort_result = tf.expand_dims(mul_image, 0, name='DistortResult')
    return jpeg_data, distort_result
# end function

#######################################################################################################################
def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir, jpeg_data_tensor, decoded_image_tensor,
                      resized_input_tensor, bottleneck_tensor, architecture):
    """
    Ensures all the training, testing, and validation bottlenecks are cached.

    Because we're likely to read the same image multiple times (if there are no distortions applied during training) it
    can speed things up a lot if we calculate the bottleneck layer values once for each image during preprocessing,
    and then just read those cached values repeatedly during training. Here we go through all the images we've found,
    calculate those values, and save them off.

    Args:
        sess: The current active TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        image_dir: Root folder string of the subfolders containing the training images.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        jpeg_data_tensor: Input tensor for jpeg data from file.
        decoded_image_tensor: The output of decoding and resizing the image.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The penultimate output layer of the graph.
        architecture: The name of the model architecture.

    Returns:
        Nothing.
    """
    how_many_bottlenecks = 0
    makeDirIfDoesNotExist(bottleneck_dir)
    for label_name, label_lists in image_lists.items():
        for category in ['training', 'testing', 'validation']:
            category_list = label_lists[category]
            for index, unused_base_name in enumerate(category_list):
                get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir, category, bottleneck_dir,
                                         jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture)
            # end for
            how_many_bottlenecks += 1
            if how_many_bottlenecks % 100 == 0:
                tf.logging.info(str(how_many_bottlenecks) + ' bottleneck files created.')
            # end if
# end function

#######################################################################################################################
def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir, category, bottleneck_dir, jpeg_data_tensor,
                             decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture):
    """
    Retrieves or calculates bottleneck values for an image.

    If a cached version of the bottleneck data exists on-disk, return that, otherwise calculate the data and save it to disk for future use.

    Args:
        sess: The current active TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Integer offset of the image we want. This will be modulo-ed by the available number of images for the label, so it can be arbitrarily large.
        image_dir: Root folder string of the subfolders containing the training images.
        category: Name string of which set to pull images from - training, testing, or validation.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        jpeg_data_tensor: The tensor to feed loaded jpeg data into.
        decoded_image_tensor: The output of decoding and resizing the image.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The output tensor for the bottleneck values.
        architecture: The name of the model architecture.

    Returns:
        Numpy array of values produced by the bottleneck layer for the image.
    """
    label_lists = image_lists[label_name]
    sub_dir = label_lists['dir']
    sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
    makeDirIfDoesNotExist(sub_dir_path)
    bottleneck_path = get_bottleneck_path(image_lists, label_name, index, bottleneck_dir, category, architecture)
    if not os.path.exists(bottleneck_path):
        create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess, jpeg_data_tensor,
                               decoded_image_tensor, resized_input_tensor, bottleneck_tensor)
    # end if

    # read in the contents of the bottleneck file as one big string
    with open(bottleneck_path, 'r') as bottleneck_file:
        bottleneckBigString = bottleneck_file.read()
    # end with

    bottleneckValues = []
    errorOccurred = False
    try:
        # split the bottleneck file contents read in as one big string into individual float values
        bottleneckValues = [float(individualString) for individualString in bottleneckBigString.split(',')]
    except ValueError:
        tf.logging.warning('Invalid float found, recreating bottleneck')
        errorOccurred = True
    # end try

    if errorOccurred:
        # if an error occurred above, create (or re-create) the bottleneck file
        create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess,
                               jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor)

        # read in the contents of the newly created bottleneck file
        with open(bottleneck_path, 'r') as bottleneck_file:
            bottleneckBigString = bottleneck_file.read()
        # end with

        # split the bottleneck file contents read in as one big string into individual float values again
        bottleneckValues = [float(individualString) for individualString in bottleneckBigString.split(',')]
    # end if
    return bottleneckValues
# end function

#######################################################################################################################
def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir, category, architecture):
    """"
    Returns a path to a bottleneck file for a label at the given index.

    Args:
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Integer offset of the image we want. This will be moduloed by the
        available number of images for the label, so it can be arbitrarily large.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        category: Name string of set to pull images from - training, testing, or
        validation.
        architecture: The name of the model architecture.

    Returns:
        File system path string to an image that meets the requested parameters.
    """
    return get_image_path(image_lists, label_name, index, bottleneck_dir, category) + '_' + architecture + '.txt'
# end function

#######################################################################################################################
def create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           decoded_image_tensor, resized_input_tensor,
                           bottleneck_tensor):
    """Create a single bottleneck file."""
    tf.logging.info('Creating bottleneck at ' + bottleneck_path)
    image_path = get_image_path(image_lists, label_name, index, image_dir, category)
    if not gfile.Exists(image_path):
        tf.logging.fatal('File does not exist %s', image_path)
    # end if
    image_data = gfile.FastGFile(image_path, 'rb').read()
    try:
        bottleneck_values = run_bottleneck_on_image(sess, image_data, jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor)
    except Exception as e:
        raise RuntimeError('Error during processing file %s (%s)' % (image_path, str(e)))
    # end try

    bottleneck_string = ','.join(str(x) for x in bottleneck_values)
    with open(bottleneck_path, 'w') as bottleneck_file:
        bottleneck_file.write(bottleneck_string)
    # end with
# end function

#######################################################################################################################
def run_bottleneck_on_image(sess, image_data, image_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor):
    """
    Runs inference on an image to extract the 'bottleneck' summary layer.
    Args:
        sess: Current active TensorFlow Session.
        image_data: String of raw JPEG data.
        image_data_tensor: Input data layer in the graph.
        decoded_image_tensor: Output of initial image resizing and preprocessing.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: Layer before the final softmax.

    Returns:
        Numpy array of bottleneck values.
    """
    # First decode the JPEG image, resize it, and rescale the pixel values.
    resized_input_values = sess.run(decoded_image_tensor, {image_data_tensor: image_data})
    # Then run it through the recognition network.
    bottleneck_values = sess.run(bottleneck_tensor, {resized_input_tensor: resized_input_values})
    bottleneck_values = np.squeeze(bottleneck_values)
    return bottleneck_values
# end function

#######################################################################################################################
def get_image_path(image_lists, label_name, index, image_dir, category):
    """"
    Returns a path to an image for a label at the given index.

    Args:
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Int offset of the image we want. This will be moduloed by the available number of images for the label, so it can be arbitrarily large.
        image_dir: Root folder string of the subfolders containing the training images.
        category: Name string of set to pull images from - training, testing, or validation.

    Returns:
        File system path string to an image that meets the requested parameters.
    """
    if label_name not in image_lists:
        tf.logging.fatal('Label does not exist %s.', label_name)
    # end if
    label_lists = image_lists[label_name]
    if category not in label_lists:
        tf.logging.fatal('Category does not exist %s.', category)
    # end if
    category_list = label_lists[category]
    if not category_list:
        tf.logging.fatal('Label %s has no images in the category %s.', label_name, category)
    # end if
    mod_index = index % len(category_list)
    base_name = category_list[mod_index]
    sub_dir = label_lists['dir']
    full_path = os.path.join(image_dir, sub_dir, base_name)
    return full_path
# end function

#######################################################################################################################
def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor, bottleneck_tensor_size, quantize_layer):
    """
    Adds a new softmax and fully-connected layer for training.

    We need to retrain the top layer to identify our new classes, so this function
    adds the right operations to the graph, along with some variables to hold the
    weights, and then sets up all the gradients for the backward pass.

    The set up for the softmax and fully-connected layers is based on:
    https://www.tensorflow.org/versions/master/tutorials/mnist/beginners/index.html

    Args:
        class_count: Integer of how many categories of things we're trying to recognize.
        final_tensor_name: Name string for the new final node that produces results.
        bottleneck_tensor: The output of the main CNN graph.
        bottleneck_tensor_size: How many entries in the bottleneck vector.
        quantize_layer: Boolean, specifying whether the newly added layer should be quantized.

    Returns:
        The tensors for the training and cross entropy results, and tensors for the bottleneck input and ground truth input.
    """
    with tf.name_scope('input'):
        bottleneck_input = tf.placeholder_with_default(bottleneck_tensor, shape=[None, bottleneck_tensor_size], name='BottleneckInputPlaceholder')
        ground_truth_input = tf.placeholder(tf.int64, [None], name='GroundTruthInput')
    # end with

    # Organizing the following ops as `final_training_ops` so they're easier to see in TensorBoard
    layer_name = 'final_training_ops'
    with tf.name_scope(layer_name):
        quantized_layer_weights = None
        quantized_layer_biases = None
        with tf.name_scope('weights'):
            initial_value = tf.truncated_normal([bottleneck_tensor_size, class_count], stddev=0.001)
            layer_weights = tf.Variable(initial_value, name='final_weights')
            if quantize_layer:
                quantized_layer_weights = quant_ops.MovingAvgQuantize(layer_weights, is_training=True)
                attachTensorBoardSummaries(quantized_layer_weights)
            # end if

            # this comment is necessary to suppress an unnecessary PyCharm warning
            # noinspection PyTypeChecker
            attachTensorBoardSummaries(layer_weights)
        # end with
        with tf.name_scope('biases'):
            layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
            if quantize_layer:
                quantized_layer_biases = quant_ops.MovingAvgQuantize(layer_biases, is_training=True)
                attachTensorBoardSummaries(quantized_layer_biases)
            # end if

            # this comment is necessary to suppress an unnecessary PyCharm warning
            # noinspection PyTypeChecker
            attachTensorBoardSummaries(layer_biases)
        # end with
        with tf.name_scope('Wx_plus_b'):
            if quantize_layer:
                logits = tf.matmul(bottleneck_input, quantized_layer_weights) + quantized_layer_biases
                logits = quant_ops.MovingAvgQuantize(logits, init_min=-32.0, init_max=32.0, is_training=True, num_bits=8,
                                                     narrow_range=False, ema_decay=0.5)
                tf.summary.histogram('pre_activations', logits)
            else:
                logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
                tf.summary.histogram('pre_activations', logits)
            # end if
        # end with
    # end with
    final_tensor = tf.nn.softmax(logits, name=final_tensor_name)

    tf.summary.histogram('activations', final_tensor)

    with tf.name_scope('cross_entropy'):
        cross_entropy_mean = tf.losses.sparse_softmax_cross_entropy(labels=ground_truth_input, logits=logits)
    # end with

    tf.summary.scalar('cross_entropy', cross_entropy_mean)

    with tf.name_scope('train'):
        optimizer = tf.train.GradientDescentOptimizer(LEARNING_RATE)
        train_step = optimizer.minimize(cross_entropy_mean)
    # end with

    return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input, final_tensor)
# end function

#######################################################################################################################
def attachTensorBoardSummaries(var):
    """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        # end with
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)
    # end with
# end function

#######################################################################################################################
def add_evaluation_step(result_tensor, ground_truth_tensor):
    """
    Inserts the operations we need to evaluate the accuracy of our results.
    Args:
        result_tensor: The new final node that produces results.
        ground_truth_tensor: The node we feed ground truth data into.
    Returns:
        Tuple of (evaluation step, prediction).
    """

    with tf.name_scope('accuracy'):
        with tf.name_scope('correct_prediction'):
            prediction = tf.argmax(result_tensor, 1)
            correct_prediction = tf.equal(prediction, ground_truth_tensor)
        # end with
        with tf.name_scope('accuracy'):
            evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        # end with
    tf.summary.scalar('accuracy', evaluation_step)
    return evaluation_step, prediction
# end function

#######################################################################################################################
def get_random_distorted_bottlenecks(sess, image_lists, how_many, category, image_dir, input_jpeg_tensor, distorted_image,
                                     resized_input_tensor, bottleneck_tensor):
    """
    Retrieves bottleneck values for training images, after distortions.

    If we're training with distortions like crops, scales, or flips, we have to recalculate the full model for every image,
    and so we can't use cached bottleneck values. Instead we find random images for the requested category, run them through
    the distortion graph, and then the full graph to get the bottleneck results for each.

    Args:
        sess: Current TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        how_many: The integer number of bottleneck values to return.
        category: Name string of which set of images to fetch - training, testing, or validation.
        image_dir: Root folder string of the subfolders containing the training images.
        input_jpeg_tensor: The input layer we feed the image data to.
        distorted_image: The output node of the distortion graph.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The bottleneck output layer of the CNN graph.

    Returns:
        List of bottleneck arrays and their corresponding ground truths.
    """
    class_count = len(image_lists.keys())
    bottlenecks = []
    ground_truths = []
    for unused_i in range(how_many):
        label_index = random.randrange(class_count)
        label_name = list(image_lists.keys())[label_index]
        image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
        image_path = get_image_path(image_lists, label_name, image_index, image_dir, category)
        if not gfile.Exists(image_path):
            tf.logging.fatal('File does not exist %s', image_path)
        # end if
        jpeg_data = gfile.FastGFile(image_path, 'rb').read()
        # Note that we materialize the distorted_image_data as a numpy array before
        # sending running inference on the image. This involves 2 memory copies and
        # might be optimized in other implementations.
        distorted_image_data = sess.run(distorted_image, {input_jpeg_tensor: jpeg_data})
        bottleneck_values = sess.run(bottleneck_tensor, {resized_input_tensor: distorted_image_data})
        bottleneck_values = np.squeeze(bottleneck_values)
        bottlenecks.append(bottleneck_values)
        ground_truths.append(label_index)
    # end for
    return bottlenecks, ground_truths
# end function

#######################################################################################################################
def get_random_cached_bottlenecks(sess, image_lists, how_many, category, bottleneck_dir, image_dir, jpeg_data_tensor,
                                  decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture):
    """
    Retrieves bottleneck values for cached images.

    If no distortions are being applied, this function can retrieve the cached bottleneck values directly from disk for
    images. It picks a random set of images from the specified category.

    Args:
        sess: Current TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        how_many: If positive, a random sample of this size will be chosen.  If negative, all bottlenecks will be retrieved.
        category: Name string of which set to pull from - training, testing, or validation.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        image_dir: Root folder string of the subfolders containing the training images.
        jpeg_data_tensor: The layer to feed jpeg image data into.
        decoded_image_tensor: The output of decoding and resizing the image.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The bottleneck output layer of the CNN graph.
        architecture: The name of the model architecture.

    Returns:
        List of bottleneck arrays, their corresponding ground truths, and the relevant filenames.
    """
    class_count = len(image_lists.keys())
    bottlenecks = []
    ground_truths = []
    filenames = []
    if how_many >= 0:
        # Retrieve a random sample of bottlenecks.
        for unused_i in range(how_many):
            label_index = random.randrange(class_count)
            label_name = list(image_lists.keys())[label_index]
            image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
            image_name = get_image_path(image_lists, label_name, image_index, image_dir, category)
            bottleneck = get_or_create_bottleneck(sess, image_lists, label_name, image_index, image_dir, category, bottleneck_dir,
                                                  jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture)
            bottlenecks.append(bottleneck)
            ground_truths.append(label_index)
            filenames.append(image_name)
        # end for
    else:
        # Retrieve all bottlenecks.
        for label_index, label_name in enumerate(image_lists.keys()):
            for image_index, image_name in enumerate(image_lists[label_name][category]):
                image_name = get_image_path(image_lists, label_name, image_index, image_dir, category)
                bottleneck = get_or_create_bottleneck(sess, image_lists, label_name, image_index, image_dir, category, bottleneck_dir,
                                                      jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture)
                bottlenecks.append(bottleneck)
                ground_truths.append(label_index)
                filenames.append(image_name)
    return bottlenecks, ground_truths, filenames
# end function

#######################################################################################################################
def save_graph_to_file(sess, graph, graph_file_name):
    output_graph_def = graph_util.convert_variables_to_constants(sess, graph.as_graph_def(), [FINAL_TENSOR_NAME])
    with gfile.FastGFile(graph_file_name, 'wb') as f:
        f.write(output_graph_def.SerializeToString())
    # end with
    return
# end function

#######################################################################################################################
if __name__ == '__main__':
    main()
# Out:
# starting program . . .
# downloading model (if necessary) . . .
# >> Downloading inception-2015-12-05.tgz 100.0%
# INFO:tensorflow:Successfully downloaded inception-2015-12-05.tgz, statinfo.st_size = 88931400 bytes
# Extracting file from  /home/jovyan/Final Project/model/inception-2015-12-05.tgz
# creating model graph . . .
# Model path:  /home/jovyan/Final Project/model/classify_image_graph_def.pb
# WARNING:tensorflow:From <ipython-input-4-767067783166>:515: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# creating image lists . . .
# INFO:tensorflow:Looking for images in 'spiral'
# INFO:tensorflow:Looking for images in 'edge'
# INFO:tensorflow:Looking for images in 'smooth'
# INFO:tensorflow:Looking for images in 'other'
# starting session . . .
# performing jpeg decoding . . .
# caching bottlenecks . . .
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103159.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107268.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106777.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107606.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102765.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107593.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106885.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/100951.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107202.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102046.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104234.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104934.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105631.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105700.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107709.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107229.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105539.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102328.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101307.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106263.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101140.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103824.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105787.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105572.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103533.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101074.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104389.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104721.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106390.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107951.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104589.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101991.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101275.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101166.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101549.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107517.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102040.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101298.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107422.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107747.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106275.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105500.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106355.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101787.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106039.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101564.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101756.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104536.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106882.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106621.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102407.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102402.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103818.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107355.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105758.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105365.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102701.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101955.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107629.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/100237.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101774.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105774.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107374.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107406.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102176.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107555.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101804.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105497.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101007.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101315.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105218.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107084.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102474.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102742.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105009.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/100008.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104040.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106705.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107524.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107563.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107972.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/100023.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103037.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104420.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102422.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101324.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103950.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103356.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101133.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105925.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107745.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103445.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102243.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107379.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107415.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104287.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/100134.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104001.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107159.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106514.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101469.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101244.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102735.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107012.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104020.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103979.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103561.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107627.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/101807.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104310.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104784.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102990.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102391.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103019.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105417.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106784.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105364.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105576.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103547.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105314.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/107064.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104314.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105613.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/105069.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104478.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/103075.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/106664.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/104624.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102433.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/spiral/102027.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100623.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/113512.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/116455.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/118048.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/118140.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115106.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/103040.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104008.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/114435.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115450.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104354.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115114.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/116667.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/102021.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100143.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/112034.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100474.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/113858.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117597.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/112263.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115662.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/116979.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106788.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115818.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/105940.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/110521.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107117.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106499.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104317.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/105513.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100986.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/113944.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104610.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100836.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/102964.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/118184.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/112586.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/113470.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/102874.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100513.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101239.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107314.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101232.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/116064.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/112345.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117268.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/111775.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104268.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107466.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101893.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106986.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115541.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/110678.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107231.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106176.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101997.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106298.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/105381.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117492.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104216.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117319.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101181.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106165.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107583.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117915.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107613.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/111858.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115858.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104830.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/114236.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/105743.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115402.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/113168.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117929.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117743.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104212.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/111834.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104398.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104041.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/102812.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101355.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100520.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104962.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/113436.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/117520.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/110808.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/110429.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107559.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101127.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101563.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106432.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104267.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101980.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/118223.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107197.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/112438.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101995.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/116201.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/115430.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100322.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/111491.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107810.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106670.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/110466.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/116946.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/118337.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/108979.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/111484.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/112873.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/108326.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/109333.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/114642.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/102863.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/103787.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/103132.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/100263.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/102982.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/103255.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107720.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106429.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107597.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/109449.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/106199.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/105764.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/109718.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107946.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/107454.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/111125.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/101374.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/edge/104723.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105279.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104612.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106000.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105772.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103707.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107272.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104281.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104440.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105447.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105991.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107553.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106040.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103444.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105459.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105020.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106781.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106923.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104602.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105082.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107298.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103626.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103718.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105331.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105648.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106841.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103224.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106044.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103758.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103260.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106896.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104703.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106230.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106725.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103348.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103900.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103731.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107573.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107480.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103902.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104764.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106018.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104141.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103907.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103645.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105870.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104387.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106170.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103610.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103393.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105755.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106973.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103323.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103386.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104196.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105762.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104769.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104414.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105541.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104709.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106028.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103353.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106105.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106206.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105581.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107055.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104159.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103072.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103233.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106463.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104977.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107521.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106800.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106829.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104611.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103819.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103191.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105507.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106652.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106689.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106773.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103904.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105092.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105088.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103354.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104460.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104243.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106124.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107527.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104173.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106694.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107388.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107383.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105258.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107394.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106612.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103955.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105868.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/102933.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103646.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104422.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106147.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106205.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104253.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104096.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105797.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104516.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104143.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104988.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107106.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107539.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107143.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106388.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105165.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107510.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104110.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105757.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107435.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106544.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106749.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107261.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107019.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107461.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106812.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103577.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/105354.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/107403.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/104929.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/102977.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/106919.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/smooth/103500.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/105257.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/101306.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/102649.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/107631.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/102159.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/105846.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/104751.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/105334.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/107831.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/100774.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/107660.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/102657.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/102998.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/103503.jpg_inception_v3.txt
# ...
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/102271.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/107560.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/107736.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/108947.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/105983.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/106079.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/103754.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/105900.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at /home/jovyan/Final Project/bottleneck_data/other/101666.jpg_inception_v3.txt
# adding final training layer . . .
# adding eval ops for final training layer . . .
# writing TensorBoard info . . .
# performing training . . .
# INFO:tensorflow:2019-03-06 00:05:23.706140: Step 0: Train accuracy = 30.0%
# INFO:tensorflow:2019-03-06 00:05:23.707551: Step 0: Cross entropy = 1.345468
# INFO:tensorflow:2019-03-06 00:05:24.531849: Step 0: Validation accuracy = 34.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:25.440757: Step 10: Train accuracy = 63.0%
# INFO:tensorflow:2019-03-06 00:05:25.441857: Step 10: Cross entropy = 1.144761
# INFO:tensorflow:2019-03-06 00:05:25.532550: Step 10: Validation accuracy = 48.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:26.424924: Step 20: Train accuracy = 59.0%
# INFO:tensorflow:2019-03-06 00:05:26.426129: Step 20: Cross entropy = 1.062922
# INFO:tensorflow:2019-03-06 00:05:26.515312: Step 20: Validation accuracy = 54.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:27.387822: Step 30: Train accuracy = 70.0%
# INFO:tensorflow:2019-03-06 00:05:27.389437: Step 30: Cross entropy = 0.966983
# INFO:tensorflow:2019-03-06 00:05:27.476313: Step 30: Validation accuracy = 70.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:28.336384: Step 40: Train accuracy = 70.0%
# INFO:tensorflow:2019-03-06 00:05:28.337602: Step 40: Cross entropy = 0.965448
# INFO:tensorflow:2019-03-06 00:05:28.421371: Step 40: Validation accuracy = 57.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:29.260383: Step 50: Train accuracy = 70.0%
# INFO:tensorflow:2019-03-06 00:05:29.261588: Step 50: Cross entropy = 0.896107
# INFO:tensorflow:2019-03-06 00:05:29.349069: Step 50: Validation accuracy = 58.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:30.201808: Step 60: Train accuracy = 61.0%
# INFO:tensorflow:2019-03-06 00:05:30.202950: Step 60: Cross entropy = 0.951784
# INFO:tensorflow:2019-03-06 00:05:30.287663: Step 60: Validation accuracy = 53.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:31.132400: Step 70: Train accuracy = 66.0%
# INFO:tensorflow:2019-03-06 00:05:31.133790: Step 70: Cross entropy = 0.865314
# INFO:tensorflow:2019-03-06 00:05:31.218682: Step 70: Validation accuracy = 52.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:32.094390: Step 80: Train accuracy = 65.0%
# INFO:tensorflow:2019-03-06 00:05:32.095478: Step 80: Cross entropy = 0.840478
# INFO:tensorflow:2019-03-06 00:05:32.181227: Step 80: Validation accuracy = 63.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:33.047335: Step 90: Train accuracy = 70.0%
# INFO:tensorflow:2019-03-06 00:05:33.049340: Step 90: Cross entropy = 0.856560
# INFO:tensorflow:2019-03-06 00:05:33.135390: Step 90: Validation accuracy = 59.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:33.995126: Step 100: Train accuracy = 67.0%
# INFO:tensorflow:2019-03-06 00:05:33.996105: Step 100: Cross entropy = 0.833168
# INFO:tensorflow:2019-03-06 00:05:34.086564: Step 100: Validation accuracy = 62.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:34.953750: Step 110: Train accuracy = 70.0%
# INFO:tensorflow:2019-03-06 00:05:34.954990: Step 110: Cross entropy = 0.882017
# INFO:tensorflow:2019-03-06 00:05:35.043707: Step 110: Validation accuracy = 61.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:35.929165: Step 120: Train accuracy = 79.0%
# INFO:tensorflow:2019-03-06 00:05:35.930326: Step 120: Cross entropy = 0.724368
# INFO:tensorflow:2019-03-06 00:05:36.017146: Step 120: Validation accuracy = 61.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:36.883977: Step 130: Train accuracy = 73.0%
# INFO:tensorflow:2019-03-06 00:05:36.885241: Step 130: Cross entropy = 0.832593
# INFO:tensorflow:2019-03-06 00:05:36.970401: Step 130: Validation accuracy = 56.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:37.828772: Step 140: Train accuracy = 75.0%
# INFO:tensorflow:2019-03-06 00:05:37.830237: Step 140: Cross entropy = 0.750965
# INFO:tensorflow:2019-03-06 00:05:37.919474: Step 140: Validation accuracy = 49.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:38.782371: Step 150: Train accuracy = 68.0%
# INFO:tensorflow:2019-03-06 00:05:38.784200: Step 150: Cross entropy = 0.821781
# INFO:tensorflow:2019-03-06 00:05:38.870871: Step 150: Validation accuracy = 62.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:39.733627: Step 160: Train accuracy = 72.0%
# INFO:tensorflow:2019-03-06 00:05:39.734825: Step 160: Cross entropy = 0.759133
# INFO:tensorflow:2019-03-06 00:05:39.818819: Step 160: Validation accuracy = 68.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:40.692385: Step 170: Train accuracy = 71.0%
# INFO:tensorflow:2019-03-06 00:05:40.693850: Step 170: Cross entropy = 0.820949
# INFO:tensorflow:2019-03-06 00:05:40.780497: Step 170: Validation accuracy = 64.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:41.646851: Step 180: Train accuracy = 67.0%
# INFO:tensorflow:2019-03-06 00:05:41.647979: Step 180: Cross entropy = 0.772964
# INFO:tensorflow:2019-03-06 00:05:41.733097: Step 180: Validation accuracy = 66.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:42.599076: Step 190: Train accuracy = 66.0%
# INFO:tensorflow:2019-03-06 00:05:42.600314: Step 190: Cross entropy = 0.724926
# INFO:tensorflow:2019-03-06 00:05:42.685242: Step 190: Validation accuracy = 60.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:43.552201: Step 200: Train accuracy = 72.0%
# INFO:tensorflow:2019-03-06 00:05:43.553570: Step 200: Cross entropy = 0.755208
# INFO:tensorflow:2019-03-06 00:05:43.640329: Step 200: Validation accuracy = 60.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:44.523984: Step 210: Train accuracy = 75.0%
# INFO:tensorflow:2019-03-06 00:05:44.525081: Step 210: Cross entropy = 0.647617
# INFO:tensorflow:2019-03-06 00:05:44.610749: Step 210: Validation accuracy = 61.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:45.475915: Step 220: Train accuracy = 76.0%
# INFO:tensorflow:2019-03-06 00:05:45.477473: Step 220: Cross entropy = 0.729569
# INFO:tensorflow:2019-03-06 00:05:45.563068: Step 220: Validation accuracy = 75.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:46.431835: Step 230: Train accuracy = 82.0%
# INFO:tensorflow:2019-03-06 00:05:46.432927: Step 230: Cross entropy = 0.680679
# INFO:tensorflow:2019-03-06 00:05:46.518565: Step 230: Validation accuracy = 62.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:47.378898: Step 240: Train accuracy = 70.0%
# INFO:tensorflow:2019-03-06 00:05:47.380188: Step 240: Cross entropy = 0.712983
# INFO:tensorflow:2019-03-06 00:05:47.467179: Step 240: Validation accuracy = 45.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:48.342010: Step 250: Train accuracy = 75.0%
# INFO:tensorflow:2019-03-06 00:05:48.343399: Step 250: Cross entropy = 0.713361
# INFO:tensorflow:2019-03-06 00:05:48.428449: Step 250: Validation accuracy = 67.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:49.830538: Step 260: Train accuracy = 75.0%
# INFO:tensorflow:2019-03-06 00:05:49.831859: Step 260: Cross entropy = 0.686378
# INFO:tensorflow:2019-03-06 00:05:49.920546: Step 260: Validation accuracy = 59.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:50.797926: Step 270: Train accuracy = 70.0%
# INFO:tensorflow:2019-03-06 00:05:50.799150: Step 270: Cross entropy = 0.763595
# INFO:tensorflow:2019-03-06 00:05:50.889809: Step 270: Validation accuracy = 68.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:51.769959: Step 280: Train accuracy = 77.0%
# INFO:tensorflow:2019-03-06 00:05:51.771264: Step 280: Cross entropy = 0.696299
# INFO:tensorflow:2019-03-06 00:05:51.857202: Step 280: Validation accuracy = 50.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:52.727109: Step 290: Train accuracy = 69.0%
# INFO:tensorflow:2019-03-06 00:05:52.728486: Step 290: Cross entropy = 0.740305
# INFO:tensorflow:2019-03-06 00:05:52.815211: Step 290: Validation accuracy = 54.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:53.682584: Step 300: Train accuracy = 78.0%
# INFO:tensorflow:2019-03-06 00:05:53.683843: Step 300: Cross entropy = 0.668818
# INFO:tensorflow:2019-03-06 00:05:53.771654: Step 300: Validation accuracy = 59.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:54.646488: Step 310: Train accuracy = 72.0%
# INFO:tensorflow:2019-03-06 00:05:54.647552: Step 310: Cross entropy = 0.711532
# INFO:tensorflow:2019-03-06 00:05:54.730891: Step 310: Validation accuracy = 63.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:55.595163: Step 320: Train accuracy = 80.0%
# INFO:tensorflow:2019-03-06 00:05:55.596462: Step 320: Cross entropy = 0.647844
# INFO:tensorflow:2019-03-06 00:05:55.684074: Step 320: Validation accuracy = 61.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:56.565482: Step 330: Train accuracy = 78.0%
# INFO:tensorflow:2019-03-06 00:05:56.566545: Step 330: Cross entropy = 0.651220
# INFO:tensorflow:2019-03-06 00:05:56.650832: Step 330: Validation accuracy = 63.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:57.515518: Step 340: Train accuracy = 74.0%
# INFO:tensorflow:2019-03-06 00:05:57.516796: Step 340: Cross entropy = 0.656105
# INFO:tensorflow:2019-03-06 00:05:57.604518: Step 340: Validation accuracy = 66.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:58.486673: Step 350: Train accuracy = 75.0%
# INFO:tensorflow:2019-03-06 00:05:58.488010: Step 350: Cross entropy = 0.669032
# INFO:tensorflow:2019-03-06 00:05:58.576624: Step 350: Validation accuracy = 62.0% (N=100)
# INFO:tensorflow:2019-03-06 00:05:59.435763: Step 360: Train accuracy = 76.0%
# INFO:tensorflow:2019-03-06 00:05:59.437392: Step 360: Cross entropy = 0.687969
# INFO:tensorflow:2019-03-06 00:05:59.520202: Step 360: Validation accuracy = 71.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:00.394351: Step 370: Train accuracy = 75.0%
# INFO:tensorflow:2019-03-06 00:06:00.395504: Step 370: Cross entropy = 0.603458
# INFO:tensorflow:2019-03-06 00:06:00.481557: Step 370: Validation accuracy = 65.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:01.356682: Step 380: Train accuracy = 80.0%
# INFO:tensorflow:2019-03-06 00:06:01.357861: Step 380: Cross entropy = 0.650903
# INFO:tensorflow:2019-03-06 00:06:01.442749: Step 380: Validation accuracy = 57.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:02.324332: Step 390: Train accuracy = 76.0%
# INFO:tensorflow:2019-03-06 00:06:02.325544: Step 390: Cross entropy = 0.643688
# INFO:tensorflow:2019-03-06 00:06:02.410768: Step 390: Validation accuracy = 49.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:03.270536: Step 400: Train accuracy = 72.0%
# INFO:tensorflow:2019-03-06 00:06:03.271990: Step 400: Cross entropy = 0.712754
# INFO:tensorflow:2019-03-06 00:06:03.359603: Step 400: Validation accuracy = 70.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:04.222211: Step 410: Train accuracy = 80.0%
# INFO:tensorflow:2019-03-06 00:06:04.223245: Step 410: Cross entropy = 0.699656
# INFO:tensorflow:2019-03-06 00:06:04.310739: Step 410: Validation accuracy = 69.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:05.179374: Step 420: Train accuracy = 83.0%
# INFO:tensorflow:2019-03-06 00:06:05.180479: Step 420: Cross entropy = 0.643541
# INFO:tensorflow:2019-03-06 00:06:05.267599: Step 420: Validation accuracy = 53.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:06.134105: Step 430: Train accuracy = 77.0%
# INFO:tensorflow:2019-03-06 00:06:06.135358: Step 430: Cross entropy = 0.632054
# INFO:tensorflow:2019-03-06 00:06:06.224093: Step 430: Validation accuracy = 61.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:07.102365: Step 440: Train accuracy = 80.0%
# INFO:tensorflow:2019-03-06 00:06:07.103654: Step 440: Cross entropy = 0.649602
# INFO:tensorflow:2019-03-06 00:06:07.190252: Step 440: Validation accuracy = 72.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:08.057447: Step 450: Train accuracy = 71.0%
# INFO:tensorflow:2019-03-06 00:06:08.058620: Step 450: Cross entropy = 0.631758
# INFO:tensorflow:2019-03-06 00:06:08.143710: Step 450: Validation accuracy = 59.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:09.030383: Step 460: Train accuracy = 74.0%
# INFO:tensorflow:2019-03-06 00:06:09.031737: Step 460: Cross entropy = 0.677353
# INFO:tensorflow:2019-03-06 00:06:09.119515: Step 460: Validation accuracy = 68.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:09.987091: Step 470: Train accuracy = 80.0%
# INFO:tensorflow:2019-03-06 00:06:09.988270: Step 470: Cross entropy = 0.569675
# INFO:tensorflow:2019-03-06 00:06:10.074727: Step 470: Validation accuracy = 56.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:10.957557: Step 480: Train accuracy = 74.0%
# INFO:tensorflow:2019-03-06 00:06:10.958886: Step 480: Cross entropy = 0.629075
# INFO:tensorflow:2019-03-06 00:06:11.045220: Step 480: Validation accuracy = 67.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:11.929960: Step 490: Train accuracy = 73.0%
# INFO:tensorflow:2019-03-06 00:06:11.931042: Step 490: Cross entropy = 0.765212
# INFO:tensorflow:2019-03-06 00:06:12.017767: Step 490: Validation accuracy = 59.0% (N=100)
# INFO:tensorflow:2019-03-06 00:06:12.805612: Step 499: Train accuracy = 76.0%
# INFO:tensorflow:2019-03-06 00:06:12.806869: Step 499: Cross entropy = 0.658906
# INFO:tensorflow:2019-03-06 00:06:12.894147: Step 499: Validation accuracy = 65.0% (N=100)
# running testing . . .
# INFO:tensorflow:Final test accuracy = 54.9% (N=51)
# writing trained graph and labbels with weights
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-4-767067783166> in <module>
#    1182 #######################################################################################################################
#    1183 if __name__ == '__main__':
# -> 1184     main()
#
# <ipython-input-4-767067783166> in main()
#     245         # write out the trained graph and labels with the weights stored as constants
#     246         print("writing trained graph and labbels with weights")
# --> 247         save_graph_to_file(sess, graph, OUTPUT_GRAPH)
#     248         with gfile.FastGFile(OUTPUT_LABELS, 'w') as f:
#     249             f.write('\n'.join(image_lists.keys()) + '\n')
#
# <ipython-input-4-767067783166> in save_graph_to_file(sess, graph, graph_file_name)
#    1175     output_graph_def = graph_util.convert_variables_to_constants(sess, graph.as_graph_def(), [FINAL_TENSOR_NAME])
#    1176     with gfile.FastGFile(graph_file_name, 'wb') as f:
# -> 1177         f.write(output_graph_def.SerializeToString())
#    1178     # end with
#    1179     return
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/lib/io/file_io.py in write(self, file_content)
#     109     with errors.raise_exception_on_not_ok_status() as status:
#     110       pywrap_tensorflow.AppendToFile(
# --> 111           compat.as_bytes(file_content), self._writable_file, status)
#     112
#     113   def read(self, n=-1):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# ResourceExhaustedError: /home/jovyan/Final Project/retrained_graph.pb; No space left on device
